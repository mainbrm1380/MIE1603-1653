# %%
# !pip install gurobipy
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
# Out:
# Requirement already satisfied: gurobipy in /usr/local/lib/python3.11/dist-packages (12.0.1)

# %%
import gurobipy as gp
from gurobipy import GRB

# test_data = [[4,2,1,1,0],[1,1,1,1,0], [3,2,1,1,1],[4,3,3,3,1],[0,0,2,2,0],[8,8,7,6,3]] #e_ij = 1 if col i exists at level j, bottom to top
test_data = [[0,2,1,1,0],[1,1,1,1,0]]

# num_Sections = 20
# num_Cols = 10
# num_Levels = 10
# min_section_cost = 100
# max_section_cost = 10000

#test_data = generate_instance(num_Sections,num_Cols,num_Levels,min_s_in_c=1,max_s_in_c=4)
#SectionCost = generate_section_costs(num_Sections,min_section_cost,max_section_cost)
SectionCost = [0,20,70]


n_cols = len(test_data)
n_levels = len(test_data[0])
# max_min_groups = 15 #min(n_cols,n_levels) #TODO: NEED NEW HEURISTIC FOR THIS
max_min_groups = 4 #min(n_cols,n_levels) #TODO: NEED NEW HEURISTIC FOR THIS
M = n_levels + 2
M_sections = max([max(i) for i in test_data]) + 1

Xgcl = [(g,c,l) for l in range(n_levels) for c in range(n_cols) for g in range(max_min_groups)]
Gs = [(g,s) for g in range(max_min_groups) for s in range(M_sections)]
Es = [(c,l,s) for s in range(M_sections) for l in range(n_levels) for c in range(n_cols)]

#c,l
S = {(i,j): test_data[i][j] for j in range(n_levels) for i in range(n_cols)}
S_bin = {(i,j,s): 1 if s >= test_data[i][j] else 0 for s in range(M_sections) for j in range(n_levels) for i in range(n_cols)}
E = {(i,j): 1 if test_data[i][j] > 0 else 0 for j in range(n_levels) for i in range(n_cols)}


# Create a new model
model = gp.Model("Grouping-Optimization")

# # Create variables

x = model.addVars(Xgcl, vtype = GRB.BINARY, name="x")

GroupCost = 100
# SectionCost = [0,100,400,800,1600,3200,6400,12800,14000]
sections = set(i for i in range(len(SectionCost)))

group_exists = model.addVars(max_min_groups, vtype = GRB.BINARY, name="group_exists")
column_in_group = model.addVars(max_min_groups, n_cols, vtype = GRB.BINARY, name="col_in_group")
level_in_group = model.addVars(max_min_groups, n_levels, vtype = GRB.BINARY, name="level_in_group")

# can these be continuous? or must be int?
group_lower_bound = model.addVars(max_min_groups, vtype = GRB.INTEGER, name="group_lb", lb = 0, ub = n_levels)
group_upper_bound = model.addVars(max_min_groups, vtype = GRB.INTEGER, name="group_ub", lb = 0, ub = n_levels)
group_level_range = model.addVars(max_min_groups, vtype = GRB.INTEGER, name="group_range", lb = 0, ub = n_levels)

#section size variables
group_section = model.addVars(Gs, vtype = GRB.BINARY, name="group_section")
element_section = model.addVars(Es, vtype=GRB.BINARY, name="element_section")
# Zs = model.addVars(Xgcl, vtype = GRB.BINARY, name = "Zs") #if group section = element section

#each group is same section
#group section has to be >= section of element
#take min of cost_of_section * num of elements with that section
#^either count # of sections in each group, and linearize cost_of_section var * # sections
#that is for integer version, binary version has binary var for which section a grou phas, times its cost, times number of elements
# or has bin var for section of each element, and multiple by cost of that section.
# 4 variations??

Zu = model.addVars(max_min_groups, n_levels, vtype = GRB.BINARY, name="Zu")
Zl = model.addVars(max_min_groups, n_levels, vtype = GRB.BINARY, name="Zl")

# %%
for c in range(n_cols):
  for l in range(n_levels):
    #sum of Xgcl over all groups must = if col at that level exists
    model.addConstr(gp.quicksum(x[g,c,l] for g in range(max_min_groups)) == E[c,l])
    model.addConstr(gp.quicksum(s * element_section[c,l,s] for s in range(M_sections)) >= S[c,l])
    # model.addConstr(gp.quicksum(element_section[c,l,s] for s in range(M_sections)) == 1)

  for l in range(1,n_levels):
    if E[c,l] == 1:
      model.addConstr(gp.quicksum(s*element_section[c,l,s] for s in range(M_sections)) >= gp.quicksum((s*element_section[c,l-1,s] for s in range(M_sections))))

for g in range(max_min_groups):
  #range of group g = upper bound - lower bound
  model.addConstr(group_level_range[g] == group_upper_bound[g] - group_lower_bound[g])

  #1 section per group
  model.addConstr(gp.quicksum(group_section[g,s] for s in range(M_sections)) == 1)

  for c in range(n_cols):
    for l in range(n_levels):

      #if element is in a group, it's section is at least the group's
      #if not in the group, it's greater than (at most) 0
      #TODO: these are problems constraints.
      model.addConstr(gp.quicksum(s * element_section[c,l,s] for s in range(M_sections)) >= gp.quicksum(s * group_section[g,s] for s in range(M_sections)) - (M_sections+1)*(1-x[g,c,l]))
      model.addConstr(gp.quicksum(s * element_section[c,l,s] for s in range(M_sections)) <= gp.quicksum(s * group_section[g,s] for s in range(M_sections)) + (M_sections+1)*(1-x[g,c,l]))

      #if element is in group, that column is in the group
      model.addConstr(column_in_group[g,c] >= x[g,c,l])

      #if element is in group, that level is in the group
      model.addConstr(level_in_group[g,l] >= x[g,c,l])

      #if element is in that group, that group exists
      model.addConstr(group_exists[g] >= x[g,c,l])

for g in range(max_min_groups):
  for l in range(n_levels):

    #calculate upper, lower level
    #NOTE: need to min(Ug) and max(Lg) for this to work
    #NOTE: in julia, everything is 1 based, might need to adjust formulation to make everything work as 0-based
    model.addConstr(l*level_in_group[g,l] <= group_upper_bound[g])
    model.addConstr(l*level_in_group[g,l] + M*(1-level_in_group[g,l]) >= group_lower_bound[g])

    #set Zl
    model.addConstr(M*Zl[g,l] >= l-group_lower_bound[g]+1)
    model.addConstr(M*(1-Zl[g,l]) >= group_lower_bound[g]-l)

    #set Zu
    model.addConstr(M*Zu[g,l] >= group_upper_bound[g]-l+1)
    model.addConstr(M*(1-Zu[g,l]) >= l-group_upper_bound[g])

    #if a level is within lower/upper bound, it's in the group
    model.addConstr(1+level_in_group[g,l] >= Zu[g,l]+Zl[g,l])

    # for c in range(n_cols):
      #if column and level are in the group, so is the element
      #todo: lazily constraint??
      # model.addConstr(column_in_group[g,c]+level_in_group[g,l] <= 1 + x[g,c,l])

# %%
def lazy_callback(model, where):
    if where == GRB.Callback.MIPSOL:  # Check if a new solution is found
        # Retrieve the values of decision variables at the current solution
        column_vals = model.cbGetSolution(column_in_group)
        level_vals = model.cbGetSolution(level_in_group)
        x_vals = model.cbGetSolution(x)

        # Iterate through indices and add violated constraints
        for g in range(max_min_groups):
            for l in range(n_levels):
                for c in range(n_cols):
                    lhs = column_vals[g, c] + level_vals[g, l]  # Left-hand side
                    rhs = 1 + x_vals[g, c, l]  # Right-hand side
                    if lhs > rhs + 1e-6:  # Constraint is violated
                        model.cbLazy(column_in_group[g, c] + level_in_group[g, l] <= 1 + x[g, c, l])

# %%
model.setObjective(gp.quicksum(element_section[c,l,s] * SectionCost[s] for s in range(M_sections)
for c in range(n_cols) for l in range(n_levels)) + GroupCost*gp.quicksum(group_exists),GRB.MINIMIZE)
# Out:
# <ipython-input-19-917216c6d508>:2: DeprecationWarning: Calling quicksum on a tupledict is deprecated, use .sum() instead.
#   for c in range(n_cols) for l in range(n_levels)) + GroupCost*gp.quicksum(group_exists),GRB.MINIMIZE)

# %%
# model.write("group-optim-toy.lp")

# Optimize model
# model.optimize()
model.Params.LazyConstraints = 1

model.optimize(lazy_callback)

ns = 0
for v in model.getVars():
    if "group_exists" in v.VarName and v.X > 0.5:
      ns += 1
        # print(f"{v.VarName}, {v.x:g}") #{v.X:g}")

print(f"Obj: {model.ObjVal:g}")
print(f"Time: {model.Runtime:g}")

print("Groups: ", ns)

print(test_data)
print(SectionCost)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Non-default parameters:
# LazyConstraints  1
#
# Optimize a model with 374 rows, 166 columns and 1044 nonzeros
# Model fingerprint: 0x5348db0b
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+00]
#   Objective range  [2e+01, 1e+02]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 1e+01]
# Presolve removed 103 rows and 26 columns
# Presolve time: 0.02s
# Presolved: 271 rows, 140 columns, 650 nonzeros
# Variable types: 0 continuous, 140 integer (128 binary)
#
# Root relaxation: objective 3.900000e+02, 97 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  390.00000    0   25          -  390.00000      -     -    0s
# H    0     0                     490.0000000  390.00000  20.4%     -    0s
#      0     0 infeasible    0       490.00000  490.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Zero half: 3
#   RLT: 9
#   BQP: 1
#   Lazy constraints: 14
#
# Explored 1 nodes (223 simplex iterations) in 0.17 seconds (0.01 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 1: 490
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.900000000000e+02, best bound 4.900000000000e+02, gap 0.0000%
#
# User-callback calls 307, time in user-callback 0.01 sec
# Obj: 490
# Time: 0.199371
# Groups:  2
# [[0, 2, 1, 1, 0], [1, 1, 1, 1, 0]]
# [0, 20, 70]

# %%
grouped_elements = np.full((n_cols, n_levels), -1)  # -1 as default (if element doesn't exist)

for g, i, j in x.keys():
    if x[g, i, j].X > 0.5:  # Check if x[g, i, j] is active
        grouped_elements[i, j] = g

print(grouped_elements)
# Out:
# [[-1  2  2  2 -1]
#  [ 0  0  0  0 -1]]

# %%
section_of_elements = np.full((n_cols, n_levels), 0)

for c, l, s in element_section.keys():
    if element_section[c, l, s].X > 0.5:
      section_of_elements[c, l] = s
    # print(f"column {c}, level {l}, section {s}: {element_section[c,l,s].X}")

print(section_of_elements)
# Out:
# [[0 2 2 2 0]
#  [1 1 1 1 0]]

# %%
def heatmap(color_vals, annot_vals):
  unique_values_1 = np.unique(color_vals)
  unique_values_1 = unique_values_1[unique_values_1 != -1]



  unique_values_2 = np.unique(annot_vals)
  unique_values_2 = unique_values_2[unique_values_2 > 0]

  palette_1 = sns.color_palette("viridis", len(unique_values_1))
  palette_2 = sns.color_palette("viridis", len(unique_values_2))

  color_dict_1 = {-1: (1, 1, 1)}  # White for -1
  for val, color in zip(unique_values_1, palette_1):
      color_dict_1[val] = color

  color_dict_2 = {0: (1, 1, 1)}  # White for 0
  for val, color in zip(unique_values_2, palette_2):
      color_dict_2[val] = color

  sorted_vals_1 = np.sort(list(color_dict_1.keys()))
  cmap_1 = mcolors.ListedColormap([color_dict_1[val] for val in sorted_vals_1])

  sorted_vals_2 = np.sort(list(color_dict_2.keys()))
  cmap_2 = mcolors.ListedColormap([color_dict_2[val] for val in sorted_vals_2])

  bounds_1 = np.append(sorted_vals_1, sorted_vals_1[-1] + 1) - .5
  norm_1 = mcolors.BoundaryNorm(bounds_1, cmap_1.N)

  bounds_2 = np.append(sorted_vals_2, sorted_vals_2[-1] + 1) - .5
  norm_2 = mcolors.BoundaryNorm(bounds_2, cmap_2.N)

  fig, axes = plt.subplots(1,2,figsize=(10,5))

  sns.heatmap(np.rot90(color_vals), annot=np.rot90(annot_vals), cmap=cmap_1, norm=norm_1,
              linewidths=0.5, linecolor="black", cbar=False, ax=axes[0])

  ax2 = sns.heatmap(np.rot90(annot_vals), annot=np.rot90(color_vals), cmap=cmap_2, norm=norm_2,
                    linewidths=.5, linecolor="black", cbar=True, ax=axes[1])

  # customizing the cbar
  cbar = ax2.collections[0].colorbar
  cbar.set_ticks(sorted_vals_2)
  cbar.set_ticklabels(sorted_vals_2)

  axes[0].set_title("Grouping of elements")
  axes[1].set_title("Section of elements")

  axes[0].axis("off")
  axes[1].axis("off")

  plt.tight_layout()
  plt.show()

# %%
heatmap(grouped_elements, section_of_elements)

# %%
def add_constraints(model):

  for c in range(n_cols):
    for l in range(n_levels):
      model.addConstr(gp.quicksum(x[g,c,l] for g in range(max_min_groups)) == E[c,l])
      model.addConstr(gp.quicksum(s * element_section[c,l,s] for s in range(M_sections)) >= S[c,l])

    for l in range(1,n_levels):
      if E[c,l] == 1:
        model.addConstr(gp.quicksum(s*element_section[c,l,s] for s in range(M_sections)) >= gp.quicksum((s*element_section[c,l-1,s] for s in range(M_sections))))

  for g in range(max_min_groups):
    model.addConstr(group_level_range[g] == group_upper_bound[g] - group_lower_bound[g])

    model.addConstr(gp.quicksum(group_section[g,s] for s in range(M_sections)) == 1)

    for c in range(n_cols):
      for l in range(n_levels):

        model.addConstr(gp.quicksum(s * element_section[c,l,s] for s in range(M_sections)) >= gp.quicksum(s * group_section[g,s] for s in range(M_sections)) - (M_sections+1)*(1-x[g,c,l]))
        model.addConstr(gp.quicksum(s * element_section[c,l,s] for s in range(M_sections)) <= gp.quicksum(s * group_section[g,s] for s in range(M_sections)) + (M_sections+1)*(1-x[g,c,l]))

        model.addConstr(column_in_group[g,c] >= x[g,c,l])

        model.addConstr(level_in_group[g,l] >= x[g,c,l])

        model.addConstr(group_exists[g] >= x[g,c,l])

  for g in range(max_min_groups):
    for l in range(n_levels):
      model.addConstr(l*level_in_group[g,l] <= group_upper_bound[g])
      # model.addConstr(l*level_in_group[g,l] + M*(1-level_in_group[g,l]) >= group_lower_bound[g])

      # model.addConstr(M*Zl[g,l] >= l-group_lower_bound[g]+1)
      # model.addConstr(M*(1-Zl[g,l]) >= group_lower_bound[g]-l)

      # model.addConstr(M*Zu[g,l] >= group_upper_bound[g]-l+1)
      # model.addConstr(M*(1-Zu[g,l]) >= l-group_upper_bound[g])

      model.addConstr(1+level_in_group[g,l] >= Zu[g,l]+Zl[g,l])

      for c in range(n_cols):
      # if column and level are in the group, so is the element
      # todo: lazily constraint??
        model.addConstr(column_in_group[g,c]+level_in_group[g,l] <= 1 + x[g,c,l])

  return model

# %%
model = gp.Model("lagrange-relaxation")

x = model.addVars(Xgcl, vtype = GRB.BINARY, name="x")

GroupCost = 100

sections = set(i for i in range(len(SectionCost)))

group_exists = model.addVars(max_min_groups, vtype = GRB.BINARY, name="group_exists")
column_in_group = model.addVars(max_min_groups, n_cols, vtype = GRB.BINARY, name="col_in_group")
level_in_group = model.addVars(max_min_groups, n_levels, vtype = GRB.BINARY, name="level_in_group")

group_lower_bound = model.addVars(max_min_groups, vtype = GRB.INTEGER, name="group_lb", lb = 0, ub = n_levels)
group_upper_bound = model.addVars(max_min_groups, vtype = GRB.INTEGER, name="group_ub", lb = 0, ub = n_levels)
group_level_range = model.addVars(max_min_groups, vtype = GRB.INTEGER, name="group_range", lb = 0, ub = n_levels)

group_section = model.addVars(Gs, vtype = GRB.BINARY, name="group_section")
element_section = model.addVars(Es, vtype=GRB.BINARY, name="element_section")

Zu = model.addVars(max_min_groups, n_levels, vtype = GRB.BINARY, name="Zu")
Zl = model.addVars(max_min_groups, n_levels, vtype = GRB.BINARY, name="Zl")

# %%
model = add_constraints(model)

# %%
lambdas = [
    {(g, l): 0.0 for g in range(max_min_groups) for l in range(n_levels)} for _ in range(5)
]

# subgradient optimization
step_size = 1.0
max_iterations = 100
best_dual = -float("inf")
for iteration in range(max_iterations):

  original_obj = GroupCost * gp.quicksum(level_in_group[g, l] for g in range(max_min_groups) for l in range(n_levels))

  lagrangian_obj = (
      original_obj +
      gp.quicksum(lambdas[0][g, l] * (group_lower_bound[g] - (l * level_in_group[g, l] + M * (1 - level_in_group[g, l])))
                  for g in range(max_min_groups) for l in range(n_levels))
      + gp.quicksum(lambdas[1][g, l] * ((l - group_lower_bound[g] + 1) - M * Zl[g, l])
                    for g in range(max_min_groups) for l in range(n_levels))
      + gp.quicksum(lambdas[2][g, l] * ((group_lower_bound[g] - l) - M * (1 - Zl[g, l]))
                    for g in range(max_min_groups) for l in range(n_levels))
      + gp.quicksum(lambdas[3][g, l] * ((group_upper_bound[g] - l + 1) - M * Zu[g, l])
                    for g in range(max_min_groups) for l in range(n_levels))
      + gp.quicksum(lambdas[4][g, l] * ((l - group_upper_bound[g]) - M * (1 - Zu[g, l]))
                    for g in range(max_min_groups) for l in range(n_levels))
  )
  model.setObjective(lagrangian_obj, GRB.MINIMIZE)

  model.optimize()




  # update best dual bound
  if model.ObjVal > best_dual:
      best_dual = model.ObjVal

  # compute subgradients
  subgradients = [
      { (g, l):group_lower_bound[g].X - l * level_in_group[g, l].X + M * (1 - level_in_group[g, l].X)
                for g in range(max_min_groups) for l in range(n_levels)},
      { (g, l):l - group_lower_bound[g].X + 1 - M * Zl[g, l].X
                    for g in range(max_min_groups) for l in range(n_levels) },
      { (g, l): group_lower_bound[g].X - l - M * (1 - Zl[g, l].X)
                    for g in range(max_min_groups) for l in range(n_levels) },
      { (g, l): group_upper_bound[g].X - l + 1 - M * Zu[g, l].X
                    for g in range(max_min_groups) for l in range(n_levels) },
      { (g, l): l - group_upper_bound[g].X - M * (1 - Zu[g, l].X)
                    for g in range(max_min_groups) for l in range(n_levels)}
  ]

  # update Lagrange multipliers
  for i in range(5):
      for g in range(max_min_groups):
          for l in range(n_levels):
              lambdas[i][g, l] = max(0, lambdas[i][g, l] - step_size * subgradients[i][g, l])

  # reduce step size
  step_size = step_size/1+iteration

  print(f"Iteration {iteration + 1}: Best dual = {best_dual}")

  if step_size < 1e-6:
      break

print("Final best dual bound:", best_dual)
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x9615b5a1
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
# Found heuristic solution: objective 400.0000000
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: cutoff, 49 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       400.00000  400.00000  0.00%     -    0s
#
# Explored 1 nodes (49 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 1: 400
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+02, best bound 4.000000000000e+02, gap 0.0000%
# Iteration 1: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xd3d16c87
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [4e+01, 1e+02]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -3314
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -3.342000e+03, 54 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -3342.000000 -3342.0000  0.00%     -    0s
#      0     0 -3342.0000    0   24 -3342.0000 -3342.0000  0.00%     -    0s
#
# Explored 1 nodes (54 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -3342 -3314
# No other solutions better than -3342
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.342000000000e+03, best bound -3.342000000000e+03, gap 0.0000%
# Iteration 2: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xc323f88a
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [9e+01, 2e+02]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -7014
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -7.042000e+03, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -7042.000000 -7042.0000  0.00%     -    0s
#      0     0 -7042.0000    0   26 -7042.0000 -7042.0000  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -7042 -7014
# No other solutions better than -7042
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -7.042000000000e+03, best bound -7.042000000000e+03, gap 0.0000%
# Iteration 3: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xae36fc64
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 3e+02]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -14428
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.448400e+04, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -14484.00000 -14484.000  0.00%     -    0s
#      0     0 -14484.000    0   24 -14484.000 -14484.000  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -14484 -14428
# No other solutions better than -14484
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.448400000000e+04, best bound -1.448400000000e+04, gap 0.0000%
# Iteration 4: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xc9add6a0
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 7e+02]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -29256
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -2.936800e+04, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -29368.00000 -29368.000  0.00%     -    0s
#      0     0 -29368.000    0   26 -29368.000 -29368.000  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -29368 -29256
# No other solutions better than -29368
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.936800000000e+04, best bound -2.936800000000e+04, gap 0.0000%
# Iteration 5: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x55401abe
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+03]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -55198
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -5.539400e+04, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -55394.00000 -55394.000  0.00%     -    0s
#      0     0 -55394.000    0   24 -55394.000 -55394.000  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.13 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -55394 -55198
# No other solutions better than -55394
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.539400000000e+04, best bound -5.539400000000e+04, gap 0.0000%
# Iteration 6: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x436e4e84
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 2e+03]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -95954
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -9.626200e+04, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -96262.00000 -96262.000  0.00%     -    0s
#      0     0 -96262.000    0   26 -96262.000 -96262.000  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.12 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -96262 -95954
# No other solutions better than -96262
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.626200000000e+04, best bound -9.626200000000e+04, gap 0.0000%
# Iteration 7: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x66416722
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 4e+03]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -155224
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.556720e+05, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -155672.0000 -155672.00  0.00%     -    0s
#      0     0 -155672.00    0   24 -155672.00 -155672.00  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -155672 -155224
# No other solutions better than -155672
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.556720000000e+05, best bound -1.556720000000e+05, gap 0.0000%
# Iteration 8: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xe31863ce
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 5e+03]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -236708
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -2.373240e+05, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -237324.0000 -237324.00  0.00%     -    0s
#      0     0 -237324.00    0   26 -237324.00 -237324.00  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -237324 -236708
# No other solutions better than -237324
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.373240000000e+05, best bound -2.373240000000e+05, gap 0.0000%
# Iteration 9: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x9af2cef5
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 8e+03]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -344106
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -3.449180e+05, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -344918.0000 -344918.00  0.00%     -    0s
#      0     0 -344918.00    0   24 -344918.00 -344918.00  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.13 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -344918 -344106
# No other solutions better than -344918
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.449180000000e+05, best bound -3.449180000000e+05, gap 0.0000%
# Iteration 10: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x900470dc
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -481118
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -4.821540e+05, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -482154.0000 -482154.00  0.00%     -    0s
#      0     0 -482154.00    0   26 -482154.00 -482154.00  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -482154 -481118
# No other solutions better than -482154
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.821540000000e+05, best bound -4.821540000000e+05, gap 0.0000%
# Iteration 11: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x11f17dcf
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -651444
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -6.527320e+05, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -652732.0000 -652732.00  0.00%     -    0s
#      0     0 -652732.00    0   24 -652732.00 -652732.00  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -652732 -651444
# No other solutions better than -652732
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.527320000000e+05, best bound -6.527320000000e+05, gap 0.0000%
# Iteration 12: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x2a88c06d
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 2e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -858784
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -8.603520e+05, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -860352.0000 -860352.00  0.00%     -    0s
#      0     0 -860352.00    0   26 -860352.00 -860352.00  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -860352 -858784
# No other solutions better than -860352
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.603520000000e+05, best bound -8.603520000000e+05, gap 0.0000%
# Iteration 13: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x2f8b6de8
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 3e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -1.10684e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.108714e+06, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -1108714.000 -1108714.0  0.00%     -    0s
#      0     0 -1108714.0    0   24 -1108714.0 -1108714.0  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -1.10871e+06 -1.10684e+06
# No other solutions better than -1.10871e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.108714000000e+06, best bound -1.108714000000e+06, gap 0.0000%
# Iteration 14: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x31214068
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 3e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -1.39931e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.03s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.401518e+06, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -1401518.000 -1401518.0  0.00%     -    0s
#      0     0 -1401518.0    0   26 -1401518.0 -1401518.0  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.17 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -1.40152e+06 -1.39931e+06
# No other solutions better than -1.40152e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.401518000000e+06, best bound -1.401518000000e+06, gap 0.0000%
# Iteration 15: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x1e60bdf3
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 4e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -1.73989e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.06s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.742464e+06, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -1742464.000 -1742464.0  0.00%     -    0s
#      0     0 -1742464.0    0   24 -1742464.0 -1742464.0  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.13 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -1.74246e+06 -1.73989e+06
# No other solutions better than -1.74246e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.742464000000e+06, best bound -1.742464000000e+06, gap 0.0000%
# Iteration 16: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xaa0dd66e
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 5e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -2.13228e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -2.135252e+06, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -2135252.000 -2135252.0  0.00%     -    0s
#      0     0 -2135252.0    0   26 -2135252.0 -2135252.0  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -2.13525e+06 -2.13228e+06
# No other solutions better than -2.13525e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.135252000000e+06, best bound -2.135252000000e+06, gap 0.0000%
# Iteration 17: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x64c5bc3a
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 6e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -2.58019e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -2.583582e+06, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -2583582.000 -2583582.0  0.00%     -    0s
#      0     0 -2583582.0    0   24 -2583582.0 -2583582.0  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -2.58358e+06 -2.58019e+06
# No other solutions better than -2.58358e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -2.583582000000e+06, best bound -2.583582000000e+06, gap 0.0000%
# Iteration 18: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x689fa190
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 7e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -3.08732e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -3.091154e+06, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -3091154.000 -3091154.0  0.00%     -    0s
#      0     0 -3091154.0    0   26 -3091154.0 -3091154.0  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -3.09115e+06 -3.08732e+06
# No other solutions better than -3.09115e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.091154000000e+06, best bound -3.091154000000e+06, gap 0.0000%
# Iteration 19: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xca392d49
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 8e+04]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -3.65736e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.07s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -3.661668e+06, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -3661668.000 -3661668.0  0.00%     -    0s
#      0     0 -3661668.0    0   24 -3661668.0 -3661668.0  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.18 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -3.66167e+06 -3.65736e+06
# No other solutions better than -3.66167e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.661668000000e+06, best bound -3.661668000000e+06, gap 0.0000%
# Iteration 20: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xaf9b6e66
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -4.29401e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.06s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -4.298824e+06, 52 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -4298824.000 -4298824.0  0.00%     -    0s
#      0     0 -4298824.0    0   26 -4298824.0 -4298824.0  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.16 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -4.29882e+06 -4.29401e+06
# No other solutions better than -4.29882e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.298824000000e+06, best bound -4.298824000000e+06, gap 0.0000%
# Iteration 21: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x7fc8942a
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -5.00097e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -5.006322e+06, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -5006322.000 -5006322.0  0.00%     -    0s
#      0     0 -5006322.0    0   24 -5006322.0 -5006322.0  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.11 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -5.00632e+06 -5.00097e+06
# No other solutions better than -5.00632e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.006322000000e+06, best bound -5.006322000000e+06, gap 0.0000%
# Iteration 22: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xb59b03b5
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -5.78195e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -5.787862e+06, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -5787862.000 -5787862.0  0.00%     -    0s
#      0     0 -5787862.0    0   26 -5787862.0 -5787862.0  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -5.78786e+06 -5.78195e+06
# No other solutions better than -5.78786e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.787862000000e+06, best bound -5.787862000000e+06, gap 0.0000%
# Iteration 23: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x0c440fe2
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 2e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -6.64065e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -6.647144e+06, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -6647144.000 -6647144.0  0.00%     -    0s
#      0     0 -6647144.0    0   24 -6647144.0 -6647144.0  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -6.64714e+06 -6.64065e+06
# No other solutions better than -6.64714e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.647144000000e+06, best bound -6.647144000000e+06, gap 0.0000%
# Iteration 24: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x356615e5
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 2e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -7.58076e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.03s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -7.587868e+06, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -7587868.000 -7587868.0  0.00%     -    0s
#      0     0 -7587868.0    0   26 -7587868.0 -7587868.0  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -7.58787e+06 -7.58076e+06
# No other solutions better than -7.58787e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -7.587868000000e+06, best bound -7.587868000000e+06, gap 0.0000%
# Iteration 25: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x7165c599
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 2e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -8.60598e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -8.613734e+06, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -8613734.000 -8613734.0  0.00%     -    0s
#      0     0 -8613734.0    0   24 -8613734.0 -8613734.0  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.17 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -8.61373e+06 -8.60598e+06
# No other solutions better than -8.61373e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.613734000000e+06, best bound -8.613734000000e+06, gap 0.0000%
# Iteration 26: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x1674279a
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 2e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -9.72001e+06
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -9.728442e+06, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -9728442.000 -9728442.0  0.00%     -    0s
#      0     0 -9728442.0    0   26 -9728442.0 -9728442.0  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.22 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -9.72844e+06 -9.72001e+06
# No other solutions better than -9.72844e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.728442000000e+06, best bound -9.728442000000e+06, gap 0.0000%
# Iteration 27: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x1ed4820f
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 2e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -1.09266e+07
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.093569e+07, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -1.09357e+07 -1.094e+07  0.00%     -    0s
#      0     0 -1.094e+07    0   24 -1.094e+07 -1.094e+07  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.09 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -1.09357e+07 -1.09266e+07
# No other solutions better than -1.09357e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.093569200000e+07, best bound -1.093569200000e+07, gap 0.0000%
# Iteration 28: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x90496cfe
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 3e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -1.22293e+07
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.223918e+07, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -1.22392e+07 -1.224e+07  0.00%     -    0s
#      0     0 -1.224e+07    0   26 -1.224e+07 -1.224e+07  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.20 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -1.22392e+07 -1.22293e+07
# No other solutions better than -1.22392e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.223918400000e+07, best bound -1.223918400000e+07, gap 0.0000%
# Iteration 29: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x6fff0af1
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 3e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -1.3632e+07
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.364262e+07, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -1.36426e+07 -1.364e+07  0.00%     -    0s
#      0     0 -1.364e+07    0   24 -1.364e+07 -1.364e+07  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -1.36426e+07 -1.3632e+07
# No other solutions better than -1.36426e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.364261800000e+07, best bound -1.364261800000e+07, gap 0.0000%
# Iteration 30: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x21ac7e8b
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 3e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -1.51383e+07
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.514969e+07, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -1.51497e+07 -1.515e+07  0.00%     -    0s
#      0     0 -1.515e+07    0   26 -1.515e+07 -1.515e+07  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.10 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -1.51497e+07 -1.51383e+07
# No other solutions better than -1.51497e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.514969400000e+07, best bound -1.514969400000e+07, gap 0.0000%
# Iteration 31: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xb912ce6c
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 4e+05]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -1.67519e+07
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -1.676411e+07, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# ...
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -4.20677e+08 -4.207e+08  0.00%     -    0s
#      0     0 -4.207e+08    0   24 -4.207e+08 -4.207e+08  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.07 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -4.20677e+08 -4.20569e+08
# No other solutions better than -4.20677e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.206765180000e+08, best bound -4.206765180000e+08, gap 0.0000%
# Iteration 90: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xa6d0528f
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -4.35063e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -4.351731e+08, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -4.35173e+08 -4.352e+08  0.00%     -    0s
#      0     0 -4.352e+08    0   26 -4.352e+08 -4.352e+08  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.05 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -4.35173e+08 -4.35063e+08
# No other solutions better than -4.35173e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.351731140000e+08, best bound -4.351731140000e+08, gap 0.0000%
# Iteration 91: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x4e7dda24
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -4.49887e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -4.499991e+08, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -4.49999e+08 -4.500e+08  0.00%     -    0s
#      0     0 -4.500e+08    0   24 -4.500e+08 -4.500e+08  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -4.49999e+08 -4.49887e+08
# No other solutions better than -4.49999e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.499990520000e+08, best bound -4.499990520000e+08, gap 0.0000%
# Iteration 92: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xbf28c4dd
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -4.65043e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -4.651580e+08, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -4.65158e+08 -4.652e+08  0.00%     -    0s
#      0     0 -4.652e+08    0   26 -4.652e+08 -4.652e+08  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.08 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -4.65158e+08 -4.65043e+08
# No other solutions better than -4.65158e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.651580320000e+08, best bound -4.651580320000e+08, gap 0.0000%
# Iteration 93: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x0b65b935
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -4.80537e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -4.806538e+08, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -4.80654e+08 -4.807e+08  0.00%     -    0s
#      0     0 -4.807e+08    0   24 -4.807e+08 -4.807e+08  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -4.80654e+08 -4.80537e+08
# No other solutions better than -4.80654e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.806537540000e+08, best bound -4.806537540000e+08, gap 0.0000%
# Iteration 94: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xcd7689f5
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -4.9637e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -4.964899e+08, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -4.96490e+08 -4.965e+08  0.00%     -    0s
#      0     0 -4.965e+08    0   26 -4.965e+08 -4.965e+08  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -4.9649e+08 -4.9637e+08
# No other solutions better than -4.9649e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -4.964899180000e+08, best bound -4.964899180000e+08, gap 0.0000%
# Iteration 95: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xba294a48
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -5.12548e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.02s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -5.126702e+08, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -5.12670e+08 -5.127e+08  0.00%     -    0s
#      0     0 -5.127e+08    0   24 -5.127e+08 -5.127e+08  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -5.1267e+08 -5.12548e+08
# No other solutions better than -5.1267e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.126702240000e+08, best bound -5.126702240000e+08, gap 0.0000%
# Iteration 96: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x9159e6df
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -5.29073e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -5.291984e+08, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -5.29198e+08 -5.292e+08  0.00%     -    0s
#      0     0 -5.292e+08    0   26 -5.292e+08 -5.292e+08  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.06 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -5.29198e+08 -5.29073e+08
# No other solutions better than -5.29198e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.291983720000e+08, best bound -5.291983720000e+08, gap 0.0000%
# Iteration 97: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x11c2de4e
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -5.4595e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -5.460781e+08, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -5.46078e+08 -5.461e+08  0.00%     -    0s
#      0     0 -5.461e+08    0   24 -5.461e+08 -5.461e+08  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -5.46078e+08 -5.4595e+08
# No other solutions better than -5.46078e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.460780620000e+08, best bound -5.460780620000e+08, gap 0.0000%
# Iteration 98: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0x88764d1d
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -5.63183e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -5.633130e+08, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -5.63313e+08 -5.633e+08  0.00%     -    0s
#      0     0 -5.633e+08    0   26 -5.633e+08 -5.633e+08  0.00%     -    0s
#
# Explored 1 nodes (52 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -5.63313e+08 -5.63183e+08
# No other solutions better than -5.63313e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.633129940000e+08, best bound -5.633129940000e+08, gap 0.0000%
# Iteration 99: Best dual = 400.0
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 314 rows, 166 columns and 964 nonzeros
# Model fingerprint: 0xd6821844
# Variable types: 0 continuous, 166 integer (154 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+02, 1e+07]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e+00, 4e+00]
#
# Loaded MIP start from previous solve with objective -5.80774e+08
#
# Presolve removed 180 rows and 110 columns
# Presolve time: 0.01s
# Presolved: 134 rows, 56 columns, 338 nonzeros
# Variable types: 0 continuous, 56 integer (56 binary)
#
# Root relaxation: objective -5.809069e+08, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    -5.80907e+08 -5.809e+08  0.00%     -    0s
#      0     0 -5.809e+08    0   24 -5.809e+08 -5.809e+08  0.00%     -    0s
#
# Explored 1 nodes (55 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 2: -5.80907e+08 -5.80774e+08
# No other solutions better than -5.80907e+08
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.809068680000e+08, best bound -5.809068680000e+08, gap 0.0000%
# Iteration 100: Best dual = 400.0
# Final best dual bound: 400.0
